# %%
# !pip install uv --quiet
# !git clone  https://github.com/abdulrahman1238/GenCV003
# %cd  /content/GenCV003
# !ls
# !uv sync
print("✅ Setup complete!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 78.0 MB/s eta 0:00:00
# Cloning into 'GenCV003'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 114 (delta 55), reused 57 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 174.79 KiB | 10.92 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/GenCV003
# configs  notebooks  pyproject.toml  README.md  src  uv.lock
# Using CPython 3.10.12 interpreter at: /usr/bin/python3.10
# Creating virtual environment at: .venv
# Resolved 57 packages in 0.83ms
# ...
# Prepared 48 packages in 1m 19s
# Installed 48 packages in 659ms
#  + contourpy==1.3.2
#  + cuda-bindings==13.3.1
#  + cuda-pathfinder==1.6.0
#  + cuda-toolkit==13.0.3.0
#  + cycler==0.12.1
#  + filelock==3.32.3
#  + fonttools==4.64.0
#  + fsspec==2026.7.0
#  + jinja2==3.1.6
#  + kiwisolver==1.5.1
#  + lightning-utilities==0.15.3
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')


# Copy the file to your current directory
# !cp "/content/drive/MyDrive/Gencv003/ddpm_epoch_80.pth" /content/GenCV003
# Out:
# Mounted at /content/drive

# %%
# !MPLBACKEND=Agg uv run python -m src.evaluation.ddpm_evaluate \
    --config configs/ddpm_config.yaml \
    --checkpoint /content/GenCV003/ddpm_epoch_80.pth
# Out:
# Using device: cuda
#
# Loading model from /content/GenCV003/ddpm_epoch_80.pth...
# ✅ Loaded checkpoint from epoch 80
# Model loaded successfully
#
# Loading test dataset for evaluation...
# Note: Real images must be in [0, 1] for FID/IS metrics
#
#
# Loaded 10000 test images in [0, 1] range
#
# ...
# Generating Visualizations
# ...
#
# 1. Generating sample grid...
# Sample grid saved to outputs/ddpm_evaluation/sample_grid.png
#
# 2. Generating denoising trajectory...
# Generating denoising trajectory for 4 images...
# This will take a few minutes (1000 steps per image)...
# Denoising trajectory saved to outputs/ddpm_evaluation/denoising_trajectory.png
#
# 3. Generating reconstruction comparison...
# Reconstructing with noise level 0.3...
# Reconstructing with noise level 0.5...
# Reconstructing with noise level 0.7...
# Reconstruction comparison saved to outputs/ddpm_evaluation/reconstruction_comparison.png
#
# ...
# Computing Quantitative Metrics
# ...
